# %%
from pynbTurtle import Turtle


t = Turtle()
t.speed(10)

t.forward(100)
t.backward(50)
t.left(90)
t.showcode('pause')
t.forward(50)
t.right(90)
t.forward(50)
# Out:
# <!-- Datei: pynbTurtle/static/turtle_canvas.html -->
#
# <!-- 1) Steuer-Buttons mit dynamischen IDs -->
# <div id="controls_c9728b93"
#   style="display:flex;
#             align-items:center;
#             justify-content:space-between;
#             gap:5px;
#             margin-bottom:5px;">
#   <!-- Canvas Buttons -->
#   <div class="canvas-controls">
#     <button id="zoomInButton_c9728b93">+</button>
#     <button id="zoomOutButton_c9728b93">−</button>
#     <button id="panUpButton_c9728b93">↑</button>
#     <button id="panLeftButton_c9728b93">←</button>
#     <button id="centerButton_c9728b93">⦿</button>
#     <button id="panRightButton_c9728b93">→</button>
#     <button id="panDownButton_c9728b93">↓</button>
#     <button id="toggleGridButton_c9728b93">Grid</button>
#     <button id="toggleTurtleButton_c9728b93">Turtle</button>
#     <button id="exportButton_c9728b93">Export</button>
#     <button id="resetButton_c9728b93">Reset</button>
#   </div>
# ...

# %%
from pynbTurtle import Turtle

t = Turtle()
t.speed(10)
t.showcode('play')
for i in range(360):
    t.forward(1)
    t.right(1)

# %%
from pynbTurtle import Turtle

def draw_square():
    for i in range(4):
        t.forward(100)
        t.right(90)


t = Turtle()
t.speed(10)
t.showcode()
draw_square()
t.backward(50)

# %%
from pynbTurtle import Turtle


t = Turtle()
t.showcode()
t.speed(10)
t.forward(20)
t.backward(10)
t.left(90)
t.forward(10)
t.right(90)
t.forward(10)
t.right(90)
t.forward(20)
t.backward(10)
t.left(90)
t.forward(10)
t.right(90)
t.forward(10)
t.right(90)
t.forward(20)
t.backward(10)
t.left(90)
t.forward(10)
t.right(90)
t.forward(10)
t.right(90)
t.forward(20)
t.backward(10)
t.left(90)
t.forward(10)
t.right(90)
t.forward(10)
t.right(90)

# %%
from pynbTurtle import Turtle

t = Turtle()
t.showcode()
t.penup()
t.forward(100)
t.pendown()
t.setposition(300, 50)
t.right(180)
t.forward(50)
t.pencolor("green")
t.forward(50)
t.pencolor("blue")
t.forward(50)

# %%
t = Turtle()
t.showcode()
draw_square()
t.forward(50)

# %%
from pynbTurtle import Turtle

t = Turtle()
t.speed(10)
def part_circle(x):
    for i in range(int(180/x)):
        t.forward(2)
        t.right(1)

def flower(leafs,circle):
    for j in range(leafs):
        for i in range(2):
            part_circle(circle)
            t.right(180-int(180/4))
        t.right(int(360/leafs))

flower(20,4)
